# %%
from pathlib import Path
IMG_EXT = {".jpg", ".jpeg", ".png", ".webp", ".bmp"}

def show_tree(folder, depth=0, max_depth=4):
    folder = Path(folder)
    n = sum(1 for f in folder.rglob("*") if f.suffix.lower() in IMG_EXT)
    print("    " * depth + f"{folder.name}/  ({n} images)")
    if depth < max_depth:
        for sub in sorted(p for p in folder.iterdir() if p.is_dir()):
            show_tree(sub, depth + 1, max_depth)

show_tree("/kaggle/input")
# Out:
# input/  (11524 images)
#     datasets/  (11524 images)
#         bhanukachamindu/  (11524 images)
#             aloe-vera-disease-dataset/  (11453 images)
#                 Aloe_Vera_Dataset_Disease/  (11453 images)
#             unseen/  (71 images)
#                 Unseen_Test_Images/  (71 images)

# %%
import os, random, hashlib, math
from pathlib import Path
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score
import matplotlib.pyplot as plt
from PIL import Image

# ---------------- SETTINGS ----------------
TRAIN_DIR = None      # None = find it automatically (looks for the Aloe_Rust / Fungal_Infection / Healthy / Leaf_Spot / Rot folders)
                      # or type the path of the folder that contains the class folders

MODEL_NAME = "EfficientNetB2"   # EfficientNetB0 | EfficientNetB1 | EfficientNetB2 | EfficientNetV2B0
BATCH = 32
EPOCHS_HEAD = 10        # phase 1: only the new classifier layer is trained
EPOCHS_FT = 25          # phase 2: the top of EfficientNet is fine-tuned too
UNFREEZE_LAST = 80      # how many EfficientNet layers to fine-tune in phase 2
LR_HEAD = 1e-3
LR_FT = 3e-5
SEED = 42
PREFIX = "disease"                        # start of the saved file names
POS_CLASS = "healthy"                  # used for the extra two-group check (lowercase class name)
POS_NAMES = ("healthy", "diseased")       # names of the two groups: POS_CLASS vs everything else
OUT_DIR = "/kaggle/working"
WEIGHTS = "imagenet"
# ------------------------------------------

IMG_SIZES = {"EfficientNetB0": 224, "EfficientNetB1": 240, "EfficientNetB2": 260, "EfficientNetV2B0": 224}
IMG_SIZE = IMG_SIZES[MODEL_NAME]
IMG_EXT = {".jpg", ".jpeg", ".png", ".webp", ".bmp"}

random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)
print("TensorFlow", tf.__version__, "| GPUs:", tf.config.list_physical_devices("GPU"))
print("Model:", MODEL_NAME, "| image size:", IMG_SIZE)
# Out:
# TensorFlow 2.20.0 | GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# Model: EfficientNetB2 | image size: 260

# %%
SPLIT_NAMES = {"train", "training", "val", "valid", "validation", "test", "testing"}

def norm(name):
    return name.strip().lower().replace("-", "_").replace(" ", "_")

def list_images(root):
    """All images under root. The class of a photo = name of the folder it sits in (lowercased)."""
    root = Path(root)
    assert root.exists(), f"Folder not found: {root}  (is the dataset added under Input? run the tree cell above)"
    paths, labels = [], []
    for f in sorted(root.rglob("*")):
        if f.is_file() and f.suffix.lower() in IMG_EXT:
            cls = norm(f.parent.name)
            if cls in SPLIT_NAMES:
                continue
            paths.append(str(f)); labels.append(cls)
    return paths, labels


def find_folder(class_names, min_match):
    """Shallowest folder under /kaggle/input whose sub-folders match at least min_match of the class names."""
    hits = []
    for dirpath, dirnames, _ in os.walk("/kaggle/input"):
        matches = len({norm(d) for d in dirnames} & set(class_names))
        if matches >= min_match:
            hits.append((len(Path(dirpath).parts), -matches, dirpath))
    return sorted(hits)[0][2] if hits else None

KNOWN_CLASSES = {"aloe_rust", "fungal_infection", "healthy", "leaf_spot", "rot"}
if TRAIN_DIR is None:
    TRAIN_DIR = find_folder(KNOWN_CLASSES, min_match=3)
    assert TRAIN_DIR, "Could not find the disease dataset under /kaggle/input. Add it under Input, or type its path in TRAIN_DIR (see the tree cell)."

print("Training folder:", TRAIN_DIR)
all_paths, all_labels = list_images(TRAIN_DIR)
CLASSES = sorted(set(all_labels))
class_to_idx = {c: i for i, c in enumerate(CLASSES)}
K = len(CLASSES); IDX = list(range(K))
counts = {c: all_labels.count(c) for c in CLASSES}
print("Classes found:", K)
for c in CLASSES:
    print(f"  {c:25s} {counts[c]:5d}  ({counts[c] / len(all_labels) * 100:4.1f}%)")
print("total:", len(all_paths))
assert 2 <= K <= 40, "Unexpected number of classes: check that TRAIN_DIR points at the folder holding the class folders."
assert min(counts.values()) >= 6, "A class has fewer than 6 photos, which is too few to split. Remove or merge it."

# 70 / 15 / 15 split, same class balance in every part
p_tr, p_tmp, y_tr, y_tmp = train_test_split(all_paths, all_labels, test_size=0.30, stratify=all_labels, random_state=SEED)
p_va, p_te, y_va, y_te = train_test_split(p_tmp, y_tmp, test_size=0.50, stratify=y_tmp, random_state=SEED)
print(f"\ntrain {len(p_tr)} | validation {len(p_va)} | test {len(p_te)}")
# Out:
# Training folder: /kaggle/input/datasets/bhanukachamindu/aloe-vera-disease-dataset/Aloe_Vera_Dataset_Disease
# Classes found: 5
#   aloe_rust                  2068  (18.1%)
#   fungal_infection           3734  (32.6%)
#   healthy                    1823  (15.9%)
#   leaf_spot                  3764  (32.9%)
#   rot                          64  ( 0.6%)
# total: 11453
#
# train 8017 | validation 1718 | test 1718

# %%
def md5(p):
    with open(p, "rb") as f:
        return hashlib.md5(f.read()).hexdigest()

def ahash(p):
    im = Image.open(p).convert("L").resize((8, 8), Image.BILINEAR)
    a = np.asarray(im, dtype=float)
    return "".join("1" if v else "0" for v in (a > a.mean()).ravel())

def dup_report(name, paths, ref_md5, ref_ah):
    exact = sum(md5(p) in ref_md5 for p in paths)
    near = sum(ahash(p) in ref_ah for p in paths)
    print(f"{name:12s}: {exact:4d} exact copies | {near:4d} exact-or-near copies of a training photo (out of {len(paths)})")

tr_md5 = {md5(p) for p in p_tr}
tr_ah = {ahash(p) for p in p_tr}
dup_report("validation", p_va, tr_md5, tr_ah)
dup_report("test", p_te, tr_md5, tr_ah)
print("\nA large number means the validation/test scores are inflated.")
# Out:
# validation  :   16 exact copies |  406 exact-or-near copies of a training photo (out of 1718)
# test        :   18 exact copies |  394 exact-or-near copies of a training photo (out of 1718)
#
# A large number means the validation/test scores are inflated.

# %%
def show_samples(paths, labels, title, n=4, max_classes=8):
    cls = sorted(set(labels))[:max_classes]
    fig, axes = plt.subplots(len(cls), n, figsize=(3 * n, 3 * len(cls)), squeeze=False)
    rng = random.Random(1)
    for ax in axes.ravel():
        ax.axis("off")
    for r, c in enumerate(cls):
        pool = [p for p, l in zip(paths, labels) if l == c]
        for k, p in enumerate(rng.sample(pool, min(n, len(pool)))):
            axes[r][k].imshow(Image.open(p).convert("RGB"))
            if k == 0:
                axes[r][k].set_title(c, loc="left", fontsize=12)
    fig.suptitle(title, fontsize=14)
    plt.tight_layout(); plt.show()

show_samples(all_paths, all_labels, "TRAINING photos")

# %%
AUTOTUNE = tf.data.AUTOTUNE

def load_img(path, label):
    img = tf.io.read_file(path)
    img = tf.io.decode_image(img, channels=3, expand_animations=False)
    img.set_shape([None, None, 3])
    img = tf.image.resize(img, (IMG_SIZE, IMG_SIZE))
    img = tf.cast(tf.round(tf.clip_by_value(img, 0, 255)), tf.uint8)   # uint8 keeps the cache small
    return img, label

def to_float(img, label):
    return tf.cast(img, tf.float32), label

flip = layers.RandomFlip("horizontal_and_vertical")
rot  = layers.RandomRotation(0.08, fill_mode="reflect")
zoom = layers.RandomZoom((-0.25, 0.10), fill_mode="reflect")

def augment(img, label):
    x = tf.cast(img, tf.float32)
    x = flip(x, training=True)
    x = rot(x, training=True)
    x = zoom(x, training=True)
    x = x / 255.0
    x = x * tf.random.uniform([], 0.75, 1.25)                              # brightness
    x = tf.image.random_contrast(x, 0.8, 1.2)                               # contrast
    x = tf.image.random_saturation(tf.clip_by_value(x, 0, 1), 0.8, 1.2)     # saturation
    x = x * tf.random.uniform([3], 0.92, 1.08)                              # small colour cast (white balance)
    x = tf.clip_by_value(x, 0.0, 1.0) * 255.0
    return x, label

def make_ds(paths, labels, training):
    y = np.array([class_to_idx[l] for l in labels], dtype=np.int32)
    ds = tf.data.Dataset.from_tensor_slices((np.array(paths), y))
    ds = ds.map(load_img, num_parallel_calls=AUTOTUNE).cache()
    if training:
        ds = ds.shuffle(len(paths), seed=SEED, reshuffle_each_iteration=True)
        ds = ds.map(augment, num_parallel_calls=AUTOTUNE)
    else:
        ds = ds.map(to_float, num_parallel_calls=AUTOTUNE)
    return ds.batch(BATCH).prefetch(AUTOTUNE)

train_ds = make_ds(p_tr, y_tr, training=True)
val_ds   = make_ds(p_va, y_va, training=False)

# common classes must not dominate: give rarer classes a bigger weight
cw = compute_class_weight("balanced", classes=np.arange(K), y=np.array([class_to_idx[l] for l in y_tr]))
class_weight = {i: float(w) for i, w in enumerate(cw)}
print("class weights:", {CLASSES[i]: round(w, 2) for i, w in class_weight.items()})

# quick look at what augmentation does to one photo
img0, _ = load_img(p_tr[0], 0)
fig, axes = plt.subplots(1, 6, figsize=(18, 3))
axes[0].imshow(img0.numpy()); axes[0].set_title("original")
for k in range(1, 6):
    axes[k].imshow(augment(img0, 0)[0].numpy().astype("uint8")); axes[k].set_title(f"augmented {k}")
for a in axes: a.axis("off")
plt.show()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789981381.027665      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1789981381.030781      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# class weights: {'aloe_rust': 1.11, 'fungal_infection': 0.61, 'healthy': 1.26, 'leaf_spot': 0.61, 'rot': 35.63}

# %%
def build_model():
    Base = getattr(keras.applications, MODEL_NAME)
    base = Base(include_top=False, weights=WEIGHTS, input_shape=(IMG_SIZE, IMG_SIZE, 3))
    base.trainable = False
    inputs = keras.Input((IMG_SIZE, IMG_SIZE, 3))          # pixel values 0-255 (EfficientNet rescales inside)
    x = base(inputs, training=False)                       # keep BatchNorm in inference mode
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(K, activation="softmax")(x)
    return keras.Model(inputs, outputs, name=PREFIX + "_" + MODEL_NAME.lower()), base

model, base = build_model()
print("parameters:", f"{model.count_params():,}")
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31790344/31790344 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# parameters: 7,775,614

# %%
def callbacks(patience):
    return [
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=patience, restore_best_weights=True, verbose=1),
        keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2, min_lr=1e-7, verbose=1),
    ]

# ---------- Phase 1: classifier head only ----------
model.compile(optimizer=keras.optimizers.Adam(LR_HEAD),
              loss="sparse_categorical_crossentropy", metrics=["accuracy"])
h1 = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS_HEAD,
               class_weight=class_weight, callbacks=callbacks(patience=4))
# Out:
# Epoch 1/10
# 2026-09-21 09:05:37.815925: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:05:37.965301: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:05:38.339611: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:05:38.482598: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:05:39.299660: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:05:39.442641: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:05:40.347373: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:05:40.512404: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1789981549.713678     147 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 250/251 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.5196 - loss: 1.0950
# 2026-09-21 09:07:03.853545: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:07:03.995357: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:07:04.329043: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:07:04.472423: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:07:05.259438: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:07:05.402246: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:07:05.548875: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:07:05.691879: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:07:06.535035: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:07:06.699152: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.5200 - loss: 1.0939
# 2026-09-21 09:07:50.867204: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:07:51.011284: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:07:51.361499: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:07:51.504375: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:07:52.278979: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:07:52.422572: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:07:53.322639: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:07:53.487084: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:07:53.651423: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 254s 511ms/step - accuracy: 0.6153 - loss: 0.8368 - val_accuracy: 0.7328 - val_loss: 0.7065 - learning_rate: 0.0010
# Epoch 2/10
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 277ms/step - accuracy: 0.7169 - loss: 0.5396 - val_accuracy: 0.7614 - val_loss: 0.6222 - learning_rate: 0.0010
# Epoch 3/10
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 69s 276ms/step - accuracy: 0.7333 - loss: 0.4947 - val_accuracy: 0.7695 - val_loss: 0.5792 - learning_rate: 0.0010
# Epoch 4/10
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 69s 275ms/step - accuracy: 0.7482 - loss: 0.4653 - val_accuracy: 0.7928 - val_loss: 0.5491 - learning_rate: 0.0010
# Epoch 5/10
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 69s 275ms/step - accuracy: 0.7555 - loss: 0.4507 - val_accuracy: 0.8003 - val_loss: 0.5125 - learning_rate: 0.0010
# Epoch 6/10
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 69s 276ms/step - accuracy: 0.7594 - loss: 0.4356 - val_accuracy: 0.8062 - val_loss: 0.4969 - learning_rate: 0.0010
# Epoch 7/10
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 69s 276ms/step - accuracy: 0.7694 - loss: 0.4222 - val_accuracy: 0.8126 - val_loss: 0.4891 - learning_rate: 0.0010
# Epoch 8/10
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 69s 275ms/step - accuracy: 0.7677 - loss: 0.4190 - val_accuracy: 0.7986 - val_loss: 0.5115 - learning_rate: 0.0010
# Epoch 9/10
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.7703 - loss: 0.4091
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 69s 274ms/step - accuracy: 0.7726 - loss: 0.4099 - val_accuracy: 0.8038 - val_loss: 0.4991 - learning_rate: 0.0010
# Epoch 10/10
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 69s 275ms/step - accuracy: 0.7737 - loss: 0.4076 - val_accuracy: 0.8021 - val_loss: 0.4890 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 10.

# %%
# ---------- Phase 2: fine-tune the top of EfficientNet ----------
base.trainable = True
for layer in base.layers[:-UNFREEZE_LAST]:
    layer.trainable = False
for layer in base.layers:
    if isinstance(layer, layers.BatchNormalization):     # never fine-tune BatchNorm statistics
        layer.trainable = False
print("trainable parameters:", f"{sum(int(np.prod(w.shape)) for w in model.trainable_weights):,}")

model.compile(optimizer=keras.optimizers.Adam(LR_FT),
              loss="sparse_categorical_crossentropy", metrics=["accuracy"])
h2 = model.fit(train_ds, validation_data=val_ds, epochs=EPOCHS_FT,
               class_weight=class_weight, callbacks=callbacks(patience=6))
# Out:
# trainable parameters: 5,527,597
# Epoch 1/25
# 2026-09-21 09:19:11.395517: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:19:11.539514: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:19:11.924830: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:19:12.068906: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:19:12.725669: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:19:12.863408: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:19:13.140798: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:19:13.305989: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 250/251 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.7798 - loss: 0.3920
# 2026-09-21 09:20:38.156410: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:20:38.299339: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:20:38.522659: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:20:38.665770: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:20:38.988927: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-21 09:20:39.154174: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 145s 415ms/step - accuracy: 0.7914 - loss: 0.3745 - val_accuracy: 0.8481 - val_loss: 0.3981 - learning_rate: 3.0000e-05
# Epoch 2/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 277ms/step - accuracy: 0.8219 - loss: 0.3153 - val_accuracy: 0.8411 - val_loss: 0.3873 - learning_rate: 3.0000e-05
# Epoch 3/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 277ms/step - accuracy: 0.8361 - loss: 0.2817 - val_accuracy: 0.8591 - val_loss: 0.3467 - learning_rate: 3.0000e-05
# Epoch 4/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 278ms/step - accuracy: 0.8513 - loss: 0.2617 - val_accuracy: 0.8847 - val_loss: 0.3057 - learning_rate: 3.0000e-05
# Epoch 5/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 278ms/step - accuracy: 0.8678 - loss: 0.2311 - val_accuracy: 0.8906 - val_loss: 0.2879 - learning_rate: 3.0000e-05
# Epoch 6/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 277ms/step - accuracy: 0.8774 - loss: 0.2124 - val_accuracy: 0.8929 - val_loss: 0.2811 - learning_rate: 3.0000e-05
# Epoch 7/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 69s 276ms/step - accuracy: 0.8882 - loss: 0.1974 - val_accuracy: 0.9069 - val_loss: 0.2372 - learning_rate: 3.0000e-05
# Epoch 8/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 277ms/step - accuracy: 0.9016 - loss: 0.1797 - val_accuracy: 0.9197 - val_loss: 0.2140 - learning_rate: 3.0000e-05
# Epoch 9/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 277ms/step - accuracy: 0.8996 - loss: 0.1700 - val_accuracy: 0.9191 - val_loss: 0.2125 - learning_rate: 3.0000e-05
# Epoch 10/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 278ms/step - accuracy: 0.9149 - loss: 0.1530 - val_accuracy: 0.9243 - val_loss: 0.2057 - learning_rate: 3.0000e-05
# Epoch 11/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 69s 276ms/step - accuracy: 0.9167 - loss: 0.1502 - val_accuracy: 0.9208 - val_loss: 0.2152 - learning_rate: 3.0000e-05
# Epoch 12/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 278ms/step - accuracy: 0.9243 - loss: 0.1346 - val_accuracy: 0.9377 - val_loss: 0.1767 - learning_rate: 3.0000e-05
# Epoch 13/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 278ms/step - accuracy: 0.9250 - loss: 0.1337 - val_accuracy: 0.9406 - val_loss: 0.1706 - learning_rate: 3.0000e-05
# Epoch 14/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 279ms/step - accuracy: 0.9338 - loss: 0.1238 - val_accuracy: 0.9430 - val_loss: 0.1612 - learning_rate: 3.0000e-05
# Epoch 15/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 277ms/step - accuracy: 0.9350 - loss: 0.1220 - val_accuracy: 0.9424 - val_loss: 0.1663 - learning_rate: 3.0000e-05
# Epoch 16/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.9363 - loss: 0.1157
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-05.
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 277ms/step - accuracy: 0.9391 - loss: 0.1115 - val_accuracy: 0.9476 - val_loss: 0.1635 - learning_rate: 3.0000e-05
# Epoch 17/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 278ms/step - accuracy: 0.9440 - loss: 0.1014 - val_accuracy: 0.9499 - val_loss: 0.1437 - learning_rate: 1.5000e-05
# Epoch 18/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 277ms/step - accuracy: 0.9516 - loss: 0.0895 - val_accuracy: 0.9482 - val_loss: 0.1449 - learning_rate: 1.5000e-05
# Epoch 19/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 278ms/step - accuracy: 0.9499 - loss: 0.0932 - val_accuracy: 0.9505 - val_loss: 0.1360 - learning_rate: 1.5000e-05
# Epoch 20/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 280ms/step - accuracy: 0.9520 - loss: 0.0886 - val_accuracy: 0.9563 - val_loss: 0.1298 - learning_rate: 1.5000e-05
# Epoch 21/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 278ms/step - accuracy: 0.9552 - loss: 0.0856 - val_accuracy: 0.9563 - val_loss: 0.1289 - learning_rate: 1.5000e-05
# Epoch 22/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 279ms/step - accuracy: 0.9540 - loss: 0.0819 - val_accuracy: 0.9593 - val_loss: 0.1260 - learning_rate: 1.5000e-05
# Epoch 23/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 278ms/step - accuracy: 0.9558 - loss: 0.0830 - val_accuracy: 0.9563 - val_loss: 0.1230 - learning_rate: 1.5000e-05
# Epoch 24/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 70s 277ms/step - accuracy: 0.9560 - loss: 0.0792 - val_accuracy: 0.9499 - val_loss: 0.1462 - learning_rate: 1.5000e-05
# Epoch 25/25
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.9544 - loss: 0.0824
# Epoch 25: ReduceLROnPlateau reducing learning rate to 7.499999810534064e-06.
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 69s 276ms/step - accuracy: 0.9550 - loss: 0.0803 - val_accuracy: 0.9540 - val_loss: 0.1341 - learning_rate: 1.5000e-05
# Restoring model weights from the end of the best epoch: 23.

# %%
acc  = h1.history["accuracy"] + h2.history["accuracy"]
vacc = h1.history["val_accuracy"] + h2.history["val_accuracy"]
loss = h1.history["loss"] + h2.history["loss"]
vloss = h1.history["val_loss"] + h2.history["val_loss"]
split = len(h1.history["loss"])
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
for a, (tr, va, name) in zip(ax, [(acc, vacc, "accuracy"), (loss, vloss, "loss")]):
    a.plot(tr, label="train"); a.plot(va, label="validation")
    a.axvline(split - 0.5, color="grey", ls="--", label="fine-tuning starts")
    a.set_title(name); a.set_xlabel("epoch"); a.legend()
plt.tight_layout(); plt.show()

# %%
def plot_cm(cm, title):
    size = max(4.6, 0.65 * K + 2.5)
    fig, ax = plt.subplots(figsize=(size, size * 0.9))
    ax.imshow(cm, cmap="Blues")
    ax.set_xticks(IDX); ax.set_xticklabels(CLASSES, rotation=45, ha="right")
    ax.set_yticks(IDX); ax.set_yticklabels(CLASSES)
    ax.set_xlabel("predicted"); ax.set_ylabel("true"); ax.set_title(title)
    for i in IDX:
        for j in IDX:
            ax.text(j, i, cm[i, j], ha="center", va="center", fontsize=9,
                    color="white" if cm[i, j] > cm.max() / 2 else "black")
    plt.tight_layout(); plt.show()

def binary_check(y, pred):
    if POS_CLASS not in class_to_idx:
        return
    a, b = POS_NAMES
    g = class_to_idx[POS_CLASS]
    t, p = (y == g), (pred == g)
    print(f"\n{a.capitalize()} vs {b} accuracy: {(t == p).mean() * 100:.2f}%")
    print(f"'{b}' photos called {a.upper()}: {int(((~t) & p).sum())} of {int((~t).sum())}")
    print(f"'{a}' photos called {b.upper()}: {int((t & ~p).sum())} of {int(t.sum())}")
    print(f"(Always answering '{b}' would score {(~t).mean() * 100:.1f}%)")

def report(y, pred, name):
    """Accuracy, per-class report, how often each class is predicted, main mix-ups, confusion matrix."""
    acc = accuracy_score(y, pred)
    f1 = f1_score(y, pred, average="macro", labels=sorted(set(y)), zero_division=0)
    print(f"\n===== {name}: accuracy {acc * 100:.2f}% | macro F1 {f1:.3f} =====\n")
    print(classification_report(y, pred, labels=IDX, target_names=CLASSES, digits=3, zero_division=0))
    print("How often each class really occurs vs how often the model predicts it")
    print("(one class predicted far more than it occurs = the model is falling back on it):")
    for i, c in enumerate(CLASSES):
        print(f"  {c:25s} true {int((y == i).sum()):4d} | predicted {int((pred == i).sum()):4d}")
    cm = confusion_matrix(y, pred, labels=IDX)
    pairs = sorted(((cm[i, j], CLASSES[i], CLASSES[j]) for i in IDX for j in IDX if i != j and cm[i, j] > 0), reverse=True)[:8]
    if pairs:
        print("\nMost common mix-ups (count: true -> predicted):")
        for n, a, b in pairs:
            print(f"  {n:4d}: {a} -> {b}")
    print("\nconfusion matrix (rows = true, columns = predicted):", CLASSES)
    print(cm)
    plot_cm(cm, name)
    binary_check(y, pred)
    return acc, f1

probs_t = model.predict(make_ds(p_te, y_te, training=False), verbose=0)
pred_t = probs_t.argmax(1)
y_t = np.array([class_to_idx[l] for l in y_te])
test_acc, test_f1 = report(y_t, pred_t, "HELD-OUT TEST split")
# Out:
# ===== HELD-OUT TEST split: accuracy 95.05% | macro F1 0.963 =====
#
#                   precision    recall  f1-score   support
#
#        aloe_rust      0.875     0.968     0.919       311
# fungal_infection      0.969     0.952     0.960       560
#          healthy      1.000     1.000     1.000       273
#        leaf_spot      0.954     0.915     0.934       565
#              rot      1.000     1.000     1.000         9
#
#         accuracy                          0.951      1718
#        macro avg      0.960     0.967     0.963      1718
#     weighted avg      0.952     0.951     0.951      1718
#
# How often each class really occurs vs how often the model predicts it
# (one class predicted far more than it occurs = the model is falling back on it):
#   aloe_rust                 true  311 | predicted  344
#   fungal_infection          true  560 | predicted  550
#   healthy                   true  273 | predicted  273
#   leaf_spot                 true  565 | predicted  542
#   rot                       true    9 | predicted    9
#
# Most common mix-ups (count: true -> predicted):
#     33: leaf_spot -> aloe_rust
#     17: fungal_infection -> leaf_spot
#     15: leaf_spot -> fungal_infection
#     10: fungal_infection -> aloe_rust
#      8: aloe_rust -> leaf_spot
#      2: aloe_rust -> fungal_infection
#
# confusion matrix (rows = true, columns = predicted): ['aloe_rust', 'fungal_infection', 'healthy', 'leaf_spot', 'rot']
# [[301   2   0   8   0]
#  [ 10 533   0  17   0]
#  [  0   0 273   0   0]
#  [ 33  15   0 517   0]
#  [  0   0   0   0   9]]
# Healthy vs diseased accuracy: 100.00%
# 'diseased' photos called HEALTHY: 0 of 1445
# 'healthy' photos called DISEASED: 0 of 273
# (Always answering 'diseased' would score 84.1%)

# %%
model_file  = f"{OUT_DIR}/{PREFIX}_{MODEL_NAME.lower()}.keras"
labels_file = f"{OUT_DIR}/{PREFIX}_{MODEL_NAME.lower()}_labels.txt"
model.save(model_file)
Path(labels_file).write_text("\n".join(CLASSES))
print("saved:", model_file, "\nsaved:", labels_file)

print("\n================ SUMMARY ================")
print(f"model         : {MODEL_NAME}   ({K} classes)")
print(f"held-out test : accuracy {test_acc * 100:.2f}% | macro F1 {test_f1:.3f}")
print("\nNext: Save Version -> Save & Run All (Commit), then open the second notebook (unseen evaluation).")
# Out:
# saved: /kaggle/working/disease_efficientnetb2.keras
# saved: /kaggle/working/disease_efficientnetb2_labels.txt
#
# ================ SUMMARY ================
# model         : EfficientNetB2   (5 classes)
# held-out test : accuracy 95.05% | macro F1 0.963
#
# Next: Save Version -> Save & Run All (Commit), then open the second notebook (unseen evaluation).

# %%
import os, zipfile
from pathlib import Path
from IPython.display import FileLink, display

# find the newest disease EfficientNet model (works in the training or in the evaluation notebook)
found = [p for root in ["/kaggle/working", "/kaggle/input"] for p in Path(root).rglob("disease_efficientnet*.keras")]
assert found, "No disease_efficientnet*.keras model found. Run the training notebook first, or add it as an input."
model = max(found, key=lambda p: p.stat().st_mtime)
labels = model.with_name(model.stem + "_labels.txt")

os.chdir("/kaggle/working")
zip_name = "aloe_disease_model.zip"
with zipfile.ZipFile(zip_name, "w", zipfile.ZIP_DEFLATED) as z:
    for f in [model, labels]:
        if f.exists():
            z.write(f, arcname=f.name)
print("Zipped:", zipfile.ZipFile(zip_name).namelist(), f"({Path(zip_name).stat().st_size / 1e6:.1f} MB)")
display(FileLink(zip_name))
# Out:
# Zipped: ['disease_efficientnetb2.keras', 'disease_efficientnetb2_labels.txt'] (69.9 MB)
# /kaggle/working/aloe_disease_model.zip
